# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates =list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3c37e4e9c9738a4e906f88db7dcd0b06'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | chhukha
# City not found. Skipping...
# Processing Record 3 of Set 1 | metro
# Processing Record 4 of Set 1 | pacific grove
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | biltine
# Processing Record 9 of Set 1 | gao
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | pingzhuang
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | namatanai
# Processing Record 16 of Set 1 | agadez
# Processing Record 17 of Set 1 | asau
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | port macquarie
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | poum
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | camacupa
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | saint-augustin
# Processing Record 29 of Set 1 | awjilah
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | arima
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | wicklow
# Processing Record 34 of Set 1 | nuuk
# Processing Record 35 of Set 1 | brovary
# Processing Record 36 of Set 1 | coruripe
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | acapulco
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | port augusta
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | gerash
# Processing Record 44 of Set 1 | nadym
# Processing Record 45 of Set 1 | nemuro
# Processing Record 46 of Set 1 | kalemie
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | namtsy
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | san quintin
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | oktyabrskiy
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | prince albert
# Processing Record 7 of Set 2 | mandalgovi
# Processing Record 8 of Set 2 | djibo
# Processing Record 9 of Set 2 | u thong
# Processing Record 10 of Set 2 | aranos
# Processing Record 11 of Set 2 | emerald
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | kondinskoye
# Processing Record 15 of Set 2 | liuhe
# Processing Record 16 of Set 2 | langsa
# Processing Record 17 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | mongo
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | pitimbu
# Processing Record 24 of Set 2 | slave lake
# Processing Record 25 of Set 2 | sheridan
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | karratha
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | sabang
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | maridi
# Processing Record 32 of Set 2 | busselton
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | maragogi
# Processing Record 35 of Set 2 | ambulu
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | hede
# Processing Record 38 of Set 2 | margate
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | severo-yeniseyskiy
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | abha
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | vestmanna
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | baruun-urt
# Processing Record 4 of Set 3 | chengde
# Processing Record 5 of Set 3 | rincon
# Processing Record 6 of Set 3 | okha
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | lanas
# Processing Record 10 of Set 3 | morro bay
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | westport
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | beauchamps
# Processing Record 15 of Set 3 | jalu
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | albany
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 3 | ambilobe
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | amalapuram
# Processing Record 24 of Set 3 | marsa matruh
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | bulgan
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | edremit
# Processing Record 29 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 3 | peterhead
# Processing Record 31 of Set 3 | cabedelo
# Processing Record 32 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 3 | kushima
# Processing Record 34 of Set 3 | potam
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | makokou
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | grand gaube
# Processing Record 40 of Set 3 | fuyu
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | morehead
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | ushtobe
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | manokwari
# Processing Record 49 of Set 3 | chalchihuites
# Processing Record 50 of Set 3 | zeya
# Processing Record 1 of Set 4 | lyngseidet
# Processing Record 2 of Set 4 | berlevag
# Processing Record 3 of Set 4 | haines junction
# Processing Record 4 of Set 4 | novaya igirma
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | bullhead city
# Processing Record 8 of Set 4 | opuwo
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | burgos
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | brandon
# Processing Record 15 of Set 4 | naklo nad notecia
# Processing Record 16 of Set 4 | brigantine
# Processing Record 17 of Set 4 | storm lake
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | matadi
# Processing Record 20 of Set 4 | mandiana
# Processing Record 21 of Set 4 | falam
# Processing Record 22 of Set 4 | aurdal
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 25 of Set 4 | strezhevoy
# Processing Record 26 of Set 4 | mbanza-ngungu
# Processing Record 27 of Set 4 | kamaishi
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | hobart
# Processing Record 30 of Set 4 | bogoslovka
# Processing Record 31 of Set 4 | atar
# Processing Record 32 of Set 4 | labuhan
# Processing Record 33 of Set 4 | havelock
# Processing Record 34 of Set 4 | ravar
# Processing Record 35 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 4 | pingliang
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | salalah
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | floro
# Processing Record 41 of Set 4 | goya
# Processing Record 42 of Set 4 | cheney
# Processing Record 43 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 4 | aswan
# Processing Record 46 of Set 4 | yining
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | shipunovo
# Processing Record 49 of Set 4 | shevchenkove
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | tutoia
# Processing Record 2 of Set 5 | cusset
# Processing Record 3 of Set 5 | los angeles
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | lukang
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | sarangani
# Processing Record 8 of Set 5 | urubicha
# Processing Record 9 of Set 5 | lasa
# Processing Record 10 of Set 5 | ialibu
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | marsh harbour
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | bandarbeyla
# Processing Record 15 of Set 5 | makung
# City not found. Skipping...
# Processing Record 16 of Set 5 | palmer
# Processing Record 17 of Set 5 | tautira
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | saint-francois
# Processing Record 21 of Set 5 | vardo
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | andilamena
# Processing Record 24 of Set 5 | luau
# Processing Record 25 of Set 5 | vacha
# Processing Record 26 of Set 5 | jamnagar
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | itaituba
# Processing Record 29 of Set 5 | colares
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | jacareacanga
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | kjollefjord
# Processing Record 35 of Set 5 | tiznit
# Processing Record 36 of Set 5 | port hedland
# Processing Record 37 of Set 5 | araouane
# Processing Record 38 of Set 5 | cap-chat
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | maua
# Processing Record 41 of Set 5 | hun
# Processing Record 42 of Set 5 | tamasi
# Processing Record 43 of Set 5 | paita
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | pangody
# Processing Record 46 of Set 5 | cayenne
# Processing Record 47 of Set 5 | sibolga
# Processing Record 48 of Set 5 | faya
# Processing Record 49 of Set 5 | kavieng
# Processing Record 50 of Set 5 | padang
# Processing Record 1 of Set 6 | aykhal
# Processing Record 2 of Set 6 | dukat
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | hay river
# Processing Record 5 of Set 6 | evensk
# Processing Record 6 of Set 6 | yerofey pavlovich
# Processing Record 7 of Set 6 | bada
# Processing Record 8 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | tsogni
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | barraute
# Processing Record 13 of Set 6 | bantou
# Processing Record 14 of Set 6 | eydhafushi
# Processing Record 15 of Set 6 | beloha
# Processing Record 16 of Set 6 | dunedin
# Processing Record 17 of Set 6 | general roca
# Processing Record 18 of Set 6 | puerto madryn
# Processing Record 19 of Set 6 | tigil
# Processing Record 20 of Set 6 | nizhniy kuranakh
# Processing Record 21 of Set 6 | inta
# Processing Record 22 of Set 6 | antofagasta
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | ballina
# Processing Record 25 of Set 6 | vrises
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | bac lieu
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | gorontalo
# Processing Record 30 of Set 6 | fairview
# Processing Record 31 of Set 6 | puerto colombia
# Processing Record 32 of Set 6 | buraydah
# Processing Record 33 of Set 6 | mansa
# Processing Record 34 of Set 6 | nikel
# Processing Record 35 of Set 6 | townsville
# Processing Record 36 of Set 6 | mezen
# Processing Record 37 of Set 6 | jan kempdorp
# Processing Record 38 of Set 6 | oranjestad
# Processing Record 39 of Set 6 | elblag
# Processing Record 40 of Set 6 | petawawa
# Processing Record 41 of Set 6 | mangan
# Processing Record 42 of Set 6 | karpathos
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | alta floresta
# Processing Record 45 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | touros
# Processing Record 48 of Set 6 | sept-iles
# Processing Record 49 of Set 6 | bereslavka
# Processing Record 50 of Set 6 | half moon bay
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | maniitsoq
# Processing Record 3 of Set 7 | progreso
# Processing Record 4 of Set 7 | luwuk
# Processing Record 5 of Set 7 | fukue
# Processing Record 6 of Set 7 | san rafael
# Processing Record 7 of Set 7 | pasni
# Processing Record 8 of Set 7 | talcahuano
# Processing Record 9 of Set 7 | fayaoue
# Processing Record 10 of Set 7 | sciacca
# Processing Record 11 of Set 7 | puerto escondido
# Processing Record 12 of Set 7 | koslan
# Processing Record 13 of Set 7 | belen
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | jizan
# Processing Record 16 of Set 7 | imbituba
# Processing Record 17 of Set 7 | kroya
# Processing Record 18 of Set 7 | jining
# Processing Record 19 of Set 7 | tecoanapa
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | thoen
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | hohhot
# Processing Record 24 of Set 7 | kapit
# Processing Record 25 of Set 7 | kitimat
# Processing Record 26 of Set 7 | cosala
# Processing Record 27 of Set 7 | the valley
# Processing Record 28 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 7 | lamu
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | quatre cocos
# Processing Record 32 of Set 7 | kruisfontein
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | riohacha
# Processing Record 35 of Set 7 | roshchino
# Processing Record 36 of Set 7 | kota kinabalu
# Processing Record 37 of Set 7 | santa maria
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | pangnirtung
# Processing Record 40 of Set 7 | miyako
# Processing Record 41 of Set 7 | itarema
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | athlone
# Processing Record 44 of Set 7 | la libertad
# Processing Record 45 of Set 7 | mitsamiouli
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | yantal
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | parakou
# Processing Record 50 of Set 7 | madison
# Processing Record 1 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 8 | sinop
# Processing Record 3 of Set 8 | kaitangata
# Processing Record 4 of Set 8 | santa maria del real
# Processing Record 5 of Set 8 | bambanglipuro
# Processing Record 6 of Set 8 | kidal
# Processing Record 7 of Set 8 | darhan
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | la joya
# Processing Record 11 of Set 8 | orapa
# Processing Record 12 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 13 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 8 | ontario
# Processing Record 15 of Set 8 | huitziltepec
# Processing Record 16 of Set 8 | tianpeng
# Processing Record 17 of Set 8 | semey
# Processing Record 18 of Set 8 | nanortalik
# Processing Record 19 of Set 8 | kutum
# Processing Record 20 of Set 8 | tessalit
# Processing Record 21 of Set 8 | sitka
# Processing Record 22 of Set 8 | cilegon
# Processing Record 23 of Set 8 | never
# Processing Record 24 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 8 | hit
# Processing Record 28 of Set 8 | bosaso
# Processing Record 29 of Set 8 | taft
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | gold coast
# Processing Record 32 of Set 8 | rawson
# Processing Record 33 of Set 8 | veseloyarsk
# Processing Record 34 of Set 8 | konevo
# Processing Record 35 of Set 8 | goulburn
# Processing Record 36 of Set 8 | balkhash
# Processing Record 37 of Set 8 | yuli
# Processing Record 38 of Set 8 | ghanzi
# Processing Record 39 of Set 8 | puri
# Processing Record 40 of Set 8 | cockburn town
# Processing Record 41 of Set 8 | fairbanks
# Processing Record 42 of Set 8 | grootfontein
# Processing Record 43 of Set 8 | kaniama
# Processing Record 44 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 8 | liverpool
# Processing Record 46 of Set 8 | umm lajj
# Processing Record 47 of Set 8 | eureka
# Processing Record 48 of Set 8 | tilichiki
# Processing Record 49 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 8 | pyay
# Processing Record 1 of Set 9 | hwange
# Processing Record 2 of Set 9 | salmas
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | concordia
# Processing Record 5 of Set 9 | ostrovnoy
# Processing Record 6 of Set 9 | homer
# Processing Record 7 of Set 9 | lebu
# Processing Record 8 of Set 9 | borama
# City not found. Skipping...
# Processing Record 9 of Set 9 | lusambo
# Processing Record 10 of Set 9 | birjand
# Processing Record 11 of Set 9 | lagoa
# Processing Record 12 of Set 9 | faanui
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | port-cartier
# Processing Record 16 of Set 9 | mujiayingzi
# Processing Record 17 of Set 9 | carauari
# Processing Record 18 of Set 9 | ballitoville
# Processing Record 19 of Set 9 | los llanos de aridane
# Processing Record 20 of Set 9 | boa vista
# Processing Record 21 of Set 9 | paka
# Processing Record 22 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 9 | bajil
# Processing Record 25 of Set 9 | san patricio
# Processing Record 26 of Set 9 | bathsheba
# Processing Record 27 of Set 9 | vila franca do campo
# Processing Record 28 of Set 9 | svetlogorsk
# Processing Record 29 of Set 9 | pevek
# Processing Record 30 of Set 9 | tiarei
# Processing Record 31 of Set 9 | sao desiderio
# Processing Record 32 of Set 9 | tabas
# Processing Record 33 of Set 9 | copiapo
# Processing Record 34 of Set 9 | suhbaatar
# Processing Record 35 of Set 9 | zhezkazgan
# Processing Record 36 of Set 9 | karachi
# Processing Record 37 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 9 | edgewater
# Processing Record 39 of Set 9 | cururupu
# Processing Record 40 of Set 9 | golden
# Processing Record 41 of Set 9 | kudahuvadhoo
# Processing Record 42 of Set 9 | novo aripuana
# Processing Record 43 of Set 9 | moron
# Processing Record 44 of Set 9 | mareeba
# Processing Record 45 of Set 9 | shimonoseki
# Processing Record 46 of Set 9 | santa rosa
# Processing Record 47 of Set 9 | malaryta
# Processing Record 48 of Set 9 | bend
# Processing Record 49 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 9 | hami
# Processing Record 1 of Set 10 | marsabit
# Processing Record 2 of Set 10 | tual
# Processing Record 3 of Set 10 | naugarzan
# City not found. Skipping...
# Processing Record 4 of Set 10 | ahipara
# Processing Record 5 of Set 10 | nouadhibou
# Processing Record 6 of Set 10 | farah
# Processing Record 7 of Set 10 | shenjiamen
# Processing Record 8 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 10 | lulea
# Processing Record 10 of Set 10 | praia da vitoria
# Processing Record 11 of Set 10 | middelkerke
# Processing Record 12 of Set 10 | ulaanbaatar
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | kavaratti
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | sterlibashevo
# Processing Record 17 of Set 10 | olavarria
# Processing Record 18 of Set 10 | shurugwi
# Processing Record 19 of Set 10 | eufaula
# Processing Record 20 of Set 10 | plettenberg bay
# Processing Record 21 of Set 10 | laguna
# Processing Record 22 of Set 10 | mount pleasant
# Processing Record 23 of Set 10 | lorengau
# Processing Record 24 of Set 10 | geraldton
# Processing Record 25 of Set 10 | chibuto
# Processing Record 26 of Set 10 | qinhuangdao
# Processing Record 27 of Set 10 | kemijarvi
# Processing Record 28 of Set 10 | ternate
# Processing Record 29 of Set 10 | perelyub
# Processing Record 30 of Set 10 | ayan
# Processing Record 31 of Set 10 | rio grande
# Processing Record 32 of Set 10 | meulaboh
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | abdulino
# Processing Record 35 of Set 10 | gisborne
# Processing Record 36 of Set 10 | leshukonskoye
# Processing Record 37 of Set 10 | san andres
# Processing Record 38 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 10 | balagansk
# Processing Record 40 of Set 10 | skegness
# Processing Record 41 of Set 10 | sao joao da barra
# Processing Record 42 of Set 10 | chute-aux-outardes
# Processing Record 43 of Set 10 | peleduy
# Processing Record 44 of Set 10 | barcelona
# Processing Record 45 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 10 | sao miguel do araguaia
# Processing Record 47 of Set 10 | isangel
# Processing Record 48 of Set 10 | khilok
# Processing Record 49 of Set 10 | emba
# Processing Record 50 of Set 10 | sanawad
# Processing Record 1 of Set 11 | belmonte
# Processing Record 2 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 3 of Set 11 | san francisco
# Processing Record 4 of Set 11 | ust-kut
# Processing Record 5 of Set 11 | airai
# Processing Record 6 of Set 11 | guerrero negro
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | wajir
# Processing Record 9 of Set 11 | valleyview
# Processing Record 10 of Set 11 | veinticinco de mayo
# Processing Record 11 of Set 11 | baltiysk
# Processing Record 12 of Set 11 | shahrud
# Processing Record 13 of Set 11 | port-gentil
# Processing Record 14 of Set 11 | muisne
# Processing Record 15 of Set 11 | polyarnyy
# Processing Record 16 of Set 11 | fortuna
# Processing Record 17 of Set 11 | tongchuan
# Processing Record 18 of Set 11 | zhanaozen
# Processing Record 19 of Set 11 | omutinskoye
# City not found. Skipping...
# Processing Record 20 of Set 11 | marsaxlokk
# Processing Record 21 of Set 11 | yanam
# Processing Record 22 of Set 11 | kirakira
# Processing Record 23 of Set 11 | nyurba
# Processing Record 24 of Set 11 | balikpapan
# Processing Record 25 of Set 11 | ferkessedougou
# Processing Record 26 of Set 11 | sao felix do xingu
# Processing Record 27 of Set 11 | nanga eboko
# Processing Record 28 of Set 11 | nunkini
# Processing Record 29 of Set 11 | kostino
# Processing Record 30 of Set 11 | egvekinot
# Processing Record 31 of Set 11 | abnub
# Processing Record 32 of Set 11 | ajdabiya
# Processing Record 33 of Set 11 | codrington
# Processing Record 34 of Set 11 | pipri
# Processing Record 35 of Set 11 | galle
# Processing Record 36 of Set 11 | benghazi
# Processing Record 37 of Set 11 | morecambe
# Processing Record 38 of Set 11 | ostersund
# Processing Record 39 of Set 11 | nelson bay
# Processing Record 40 of Set 11 | roswell
# Processing Record 41 of Set 11 | norsup
# Processing Record 42 of Set 11 | bratsk
# Processing Record 43 of Set 11 | rocha
# Processing Record 44 of Set 11 | khash
# Processing Record 45 of Set 11 | gaffney
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | east moline
# Processing Record 48 of Set 11 | banyo
# Processing Record 49 of Set 11 | okhotsk
# Processing Record 50 of Set 11 | manicore
# Processing Record 1 of Set 12 | the pas
# Processing Record 2 of Set 12 | chissamba
# Processing Record 3 of Set 12 | zarubino
# Processing Record 4 of Set 12 | dabhol
# Processing Record 5 of Set 12 | esso
# Processing Record 6 of Set 12 | manama
# Processing Record 7 of Set 12 | wanning
# Processing Record 8 of Set 12 | yulara
# Processing Record 9 of Set 12 | pio xii
# Processing Record 10 of Set 12 | rosario oeste
# Processing Record 11 of Set 12 | ixtapa
# Processing Record 12 of Set 12 | camapua
# Processing Record 13 of Set 12 | vila
# Processing Record 14 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 12 | santa isabel do rio negro
# Processing Record 16 of Set 12 | amahai
# Processing Record 17 of Set 12 | churapcha
# Processing Record 18 of Set 12 | frontera
# Processing Record 19 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 20 of Set 12 | montepuez
# Processing Record 21 of Set 12 | staryy nadym
# Processing Record 22 of Set 12 | sakakah
# Processing Record 23 of Set 12 | victoria
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | ilulissat
# Processing Record 26 of Set 12 | simao
# Processing Record 27 of Set 12 | bundaberg
# Processing Record 28 of Set 12 | trairi
# Processing Record 29 of Set 12 | upata
# Processing Record 30 of Set 12 | mabaruma
# Processing Record 31 of Set 12 | banjar
# Processing Record 32 of Set 12 | plouzane
# Processing Record 33 of Set 12 | chernyshevskiy
# Processing Record 34 of Set 12 | sangar
# Processing Record 35 of Set 12 | antalaha
# Processing Record 36 of Set 12 | kurskaya
# Processing Record 37 of Set 12 | powell
# Processing Record 38 of Set 12 | smithers
# Processing Record 39 of Set 12 | road town
# Processing Record 40 of Set 12 | flin flon
# Processing Record 41 of Set 12 | honiton
# Processing Record 42 of Set 12 | yerbogachen
# Processing Record 43 of Set 12 | hervey bay
# Processing Record 44 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 12 | conde
# Processing Record 46 of Set 12 | bria
# Processing Record 47 of Set 12 | altamont
# Processing Record 48 of Set 12 | alugan
# Processing Record 49 of Set 12 | grenaa
# Processing Record 50 of Set 12 | ixcaquixtla
# City not found. Skipping...
# Processing Record 1 of Set 13 | portland
# Processing Record 2 of Set 13 | sola
# Processing Record 3 of Set 13 | bulacan
# Processing Record 4 of Set 13 | caravelas
# Processing Record 5 of Set 13 | tacoronte
# Processing Record 6 of Set 13 | tevaitoa
# Processing Record 7 of Set 13 | san juan
# Processing Record 8 of Set 13 | yazman
# Processing Record 9 of Set 13 | cintalapa
# Processing Record 10 of Set 13 | kansk
# Processing Record 11 of Set 13 | gvarv
# Processing Record 12 of Set 13 | kropotkin
# Processing Record 13 of Set 13 | gouyave
# Processing Record 14 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | gornopravdinsk
# Processing Record 17 of Set 13 | olafsvik
# Processing Record 18 of Set 13 | ahuimanu
# Processing Record 19 of Set 13 | kuah
# Processing Record 20 of Set 13 | minas
# Processing Record 21 of Set 13 | onverwacht
# Processing Record 22 of Set 13 | vostok
# Processing Record 23 of Set 13 | kasulu
# Processing Record 24 of Set 13 | sinnamary
# Processing Record 25 of Set 13 | amboasary
# Processing Record 26 of Set 13 | budogoshch
# Processing Record 27 of Set 13 | takoradi
# Processing Record 28 of Set 13 | murdochville
# Processing Record 29 of Set 13 | atherton
# Processing Record 30 of Set 13 | qandala
# Processing Record 31 of Set 13 | klaksvik
# Processing Record 32 of Set 13 | taywarah
# Processing Record 33 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 13 | berberati
# Processing Record 35 of Set 13 | soligalich
# Processing Record 36 of Set 13 | seoul
# Processing Record 37 of Set 13 | vuktyl
# Processing Record 38 of Set 13 | tuatapere
# Processing Record 39 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 40 of Set 13 | glubokiy
# Processing Record 41 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 13 | prado
# Processing Record 43 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 13 | krasnoselkup
# Processing Record 45 of Set 13 | trinidad
# Processing Record 46 of Set 13 | mount gambier
# Processing Record 47 of Set 13 | lanxi
# Processing Record 48 of Set 13 | funtua
# Processing Record 49 of Set 13 | daru
# Processing Record 50 of Set 13 | colon
# Processing Record 1 of Set 14 | zapolyarnyy
# Processing Record 2 of Set 14 | vysokogornyy
# Processing Record 3 of Set 14 | concarneau
# Processing Record 4 of Set 14 | liyang
# Processing Record 5 of Set 14 | chadiza
# Processing Record 6 of Set 14 | mahibadhoo
# Processing Record 7 of Set 14 | zheleznodorozhnyy
# Processing Record 8 of Set 14 | yeovil
# Processing Record 9 of Set 14 | mount isa
# Processing Record 10 of Set 14 | alyangula
# Processing Record 11 of Set 14 | cabinda
# Processing Record 12 of Set 14 | kontagora
# Processing Record 13 of Set 14 | pirgos
# Processing Record 14 of Set 14 | kashi
# Processing Record 15 of Set 14 | moranbah
# Processing Record 16 of Set 14 | viedma
# Processing Record 17 of Set 14 | pundaguitan
# Processing Record 18 of Set 14 | chino valley
# Processing Record 19 of Set 14 | garhi khairo
# Processing Record 20 of Set 14 | qui nhon
# Processing Record 21 of Set 14 | lagunas
# Processing Record 22 of Set 14 | phan thiet
# Processing Record 23 of Set 14 | suratgarh
# Processing Record 24 of Set 14 | wad madani
# Processing Record 25 of Set 14 | itahari
# City not found. Skipping...
# Processing Record 26 of Set 14 | solnechnyy
# Processing Record 27 of Set 14 | sterling
# Processing Record 28 of Set 14 | thai binh
# Processing Record 29 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 30 of Set 14 | kambove
# Processing Record 31 of Set 14 | marevo
# Processing Record 32 of Set 14 | ucluelet
# Processing Record 33 of Set 14 | bam
# Processing Record 34 of Set 14 | kincardine
# Processing Record 35 of Set 14 | prince rupert
# Processing Record 36 of Set 14 | tromso
# Processing Record 37 of Set 14 | olinda
# Processing Record 38 of Set 14 | katobu
# Processing Record 39 of Set 14 | tanete
# Processing Record 40 of Set 14 | byron bay
# Processing Record 41 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 14 | el olivar
# Processing Record 43 of Set 14 | lazo
# Processing Record 44 of Set 14 | bokovskaya
# Processing Record 45 of Set 14 | lavrentiya
# Processing Record 46 of Set 14 | yatou
# Processing Record 47 of Set 14 | stephenville
# Processing Record 48 of Set 14 | sungairaya
# Processing Record 49 of Set 14 | xichang
# Processing Record 50 of Set 14 | krasnoarmeysk
# Processing Record 1 of Set 15 | kangaatsiaq
# Processing Record 2 of Set 15 | teguldet
# Processing Record 3 of Set 15 | beira
# Processing Record 4 of Set 15 | santiago de cao
# Processing Record 5 of Set 15 | dimona
# Processing Record 6 of Set 15 | kedrovyy
# Processing Record 7 of Set 15 | te anau
# Processing Record 8 of Set 15 | narasannapeta
# Processing Record 9 of Set 15 | adre
# Processing Record 10 of Set 15 | ust-tsilma
# Processing Record 11 of Set 15 | faro
# Processing Record 12 of Set 15 | quelimane
# Processing Record 13 of Set 15 | duzce
# Processing Record 14 of Set 15 | ganzhou
# Processing Record 15 of Set 15 | gajraula
# Processing Record 16 of Set 15 | melfi
# Processing Record 17 of Set 15 | kununurra
# Processing Record 18 of Set 15 | nanakuli
# Processing Record 19 of Set 15 | changping
# Processing Record 20 of Set 15 | huilong
# Processing Record 21 of Set 15 | ipojuca
# Processing Record 22 of Set 15 | antanifotsy
# Processing Record 23 of Set 15 | sobolevo
# Processing Record 24 of Set 15 | nishihara
# Processing Record 25 of Set 15 | kaliua
# Processing Record 26 of Set 15 | shouguang
# Processing Record 27 of Set 15 | knysna
# Processing Record 28 of Set 15 | ryotsu
# Processing Record 29 of Set 15 | amherst
# Processing Record 30 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 15 | thinadhoo
# Processing Record 32 of Set 15 | hearst
# Processing Record 33 of Set 15 | paamiut
# Processing Record 34 of Set 15 | cap malheureux
# Processing Record 35 of Set 15 | san antonio
# Processing Record 36 of Set 15 | edd
# Processing Record 37 of Set 15 | tamworth
# Processing Record 38 of Set 15 | samarai
# Processing Record 39 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 15 | loa janan
# Processing Record 41 of Set 15 | vanimo
# Processing Record 42 of Set 15 | hobyo
# Processing Record 43 of Set 15 | kirkenaer
# Processing Record 44 of Set 15 | bud
# Processing Record 45 of Set 15 | sampit
# Processing Record 46 of Set 15 | axim
# Processing Record 47 of Set 15 | filadelfia
# Processing Record 48 of Set 15 | san jose
# Processing Record 49 of Set 15 | virginia beach
# Processing Record 50 of Set 15 | tahta
# Processing Record 1 of Set 16 | marzuq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_name = city.title()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | palmer
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | calubcub
# City not found. Skipping...
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | bereznik
# Processing Record 12 of Set 1 | trimbak
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | bambanglipuro
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | inhambane
# Processing Record 20 of Set 1 | ulaanbaatar
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | abha
# Processing Record 23 of Set 1 | svetlogorsk
# Processing Record 24 of Set 1 | puro
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | namatanai
# Processing Record 27 of Set 1 | bathsheba
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | goycay
# City not found. Skipping...
# Processing Record 31 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | mareeba
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | onega
# Processing Record 36 of Set 1 | lerwick
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | roma
# Processing Record 42 of Set 1 | tecoanapa
# Processing Record 43 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 1 | qasigiannguit
# Processing Record 45 of Set 1 | christchurch
# Processing Record 46 of Set 1 | pangnirtung
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | hofn
# Processing Record 50 of Set 1 | juneau
# Processing Record 1 of Set 2 | bandarbeyla
# Processing Record 2 of Set 2 | sala
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | kokstad
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | gazojak
# Processing Record 8 of Set 2 | gornopravdinsk
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | kieta
# Processing Record 13 of Set 2 | tomsk
# Processing Record 14 of Set 2 | cockburn town
# Processing Record 15 of Set 2 | quatre cocos
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | pangai
# Processing Record 18 of Set 2 | kenai
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | mount gambier
# Processing Record 21 of Set 2 | te anau
# Processing Record 22 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 2 | maarianhamina
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | nouakchott
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | haines junction
# Processing Record 30 of Set 2 | tateyama
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | nyurba
# Processing Record 33 of Set 2 | tongren
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | batagay-alyta
# Processing Record 36 of Set 2 | san cristobal
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | fare
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | andenes
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | half moon bay
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | ostrovnoy
# Processing Record 49 of Set 2 | gandajika
# Processing Record 50 of Set 2 | ulaangom
# Processing Record 1 of Set 3 | forio
# Processing Record 2 of Set 3 | mogadishu
# Processing Record 3 of Set 3 | kaeo
# Processing Record 4 of Set 3 | khandyga
# Processing Record 5 of Set 3 | ballina
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | raga
# Processing Record 8 of Set 3 | lubango
# Processing Record 9 of Set 3 | hargeysa
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | artigas
# Processing Record 13 of Set 3 | somerset west
# Processing Record 14 of Set 3 | skibbereen
# Processing Record 15 of Set 3 | waingapu
# Processing Record 16 of Set 3 | ghanzi
# Processing Record 17 of Set 3 | yebaishou
# Processing Record 18 of Set 3 | hualmay
# Processing Record 19 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 3 | takoradi
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | kefamenanu
# Processing Record 23 of Set 3 | taywarah
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | avera
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | coquimbo
# Processing Record 29 of Set 3 | resistencia
# Processing Record 30 of Set 3 | vila velha
# Processing Record 31 of Set 3 | lourdes
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | karasjok
# Processing Record 34 of Set 3 | kharhial
# Processing Record 35 of Set 3 | fountain
# Processing Record 36 of Set 3 | miramar
# Processing Record 37 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | nangong
# Processing Record 40 of Set 3 | ahipara
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | vao
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | port lincoln
# Processing Record 46 of Set 3 | sandpoint
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | port hedland
# Processing Record 49 of Set 3 | isangel
# Processing Record 50 of Set 3 | pevek
# Processing Record 1 of Set 4 | villefontaine
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | tual
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | oskemen
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 4 | mitsamiouli
# Processing Record 11 of Set 4 | omsukchan
# Processing Record 12 of Set 4 | wajid
# Processing Record 13 of Set 4 | butaritari
# Processing Record 14 of Set 4 | walvis bay
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | morehead
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | puerto del rosario
# Processing Record 20 of Set 4 | nishihara
# Processing Record 21 of Set 4 | mercedes
# Processing Record 22 of Set 4 | nokaneng
# Processing Record 23 of Set 4 | hibbing
# Processing Record 24 of Set 4 | puerto ayora
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | labuhan
# Processing Record 27 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 4 | aykhal
# Processing Record 29 of Set 4 | edson
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | abu kamal
# Processing Record 32 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 4 | riohacha
# Processing Record 34 of Set 4 | honiara
# Processing Record 35 of Set 4 | gondar
# Processing Record 36 of Set 4 | santa marta de tormes
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | sabang
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | kota belud
# Processing Record 41 of Set 4 | praia da vitoria
# Processing Record 42 of Set 4 | carballo
# Processing Record 43 of Set 4 | sosnovo
# Processing Record 44 of Set 4 | hoquiam
# Processing Record 45 of Set 4 | krasnodon
# Processing Record 46 of Set 4 | nove mesto na morave
# Processing Record 47 of Set 4 | atar
# Processing Record 48 of Set 4 | marawi
# Processing Record 49 of Set 4 | kaoma
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | lakatoro
# Processing Record 4 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 5 | butterworth
# Processing Record 6 of Set 5 | dikson
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | piacabucu
# Processing Record 9 of Set 5 | nantucket
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | mangrol
# Processing Record 12 of Set 5 | heves
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | rokytne
# Processing Record 15 of Set 5 | saint george
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | zyryanka
# Processing Record 18 of Set 5 | kiunga
# Processing Record 19 of Set 5 | mokhsogollokh
# Processing Record 20 of Set 5 | leeton
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | linxia
# Processing Record 23 of Set 5 | lavrentiya
# Processing Record 24 of Set 5 | beringovskiy
# Processing Record 25 of Set 5 | mar del plata
# Processing Record 26 of Set 5 | georgetown
# Processing Record 27 of Set 5 | tukrah
# Processing Record 28 of Set 5 | providencia
# Processing Record 29 of Set 5 | ayan
# Processing Record 30 of Set 5 | maputo
# Processing Record 31 of Set 5 | spornoye
# Processing Record 32 of Set 5 | dawlatabad
# Processing Record 33 of Set 5 | mildura
# Processing Record 34 of Set 5 | general roca
# Processing Record 35 of Set 5 | tabuk
# Processing Record 36 of Set 5 | qeshm
# Processing Record 37 of Set 5 | quesnel
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 5 | sumbe
# Processing Record 41 of Set 5 | saint-georges
# Processing Record 42 of Set 5 | valkla
# Processing Record 43 of Set 5 | ban phai
# Processing Record 44 of Set 5 | lumeje
# Processing Record 45 of Set 5 | ziro
# Processing Record 46 of Set 5 | flinders
# Processing Record 47 of Set 5 | saint-joseph
# Processing Record 48 of Set 5 | les cayes
# Processing Record 49 of Set 5 | methoni
# Processing Record 50 of Set 5 | nabire
# Processing Record 1 of Set 6 | parry sound
# Processing Record 2 of Set 6 | ashtabula
# Processing Record 3 of Set 6 | srednekolymsk
# Processing Record 4 of Set 6 | kargil
# Processing Record 5 of Set 6 | kushima
# Processing Record 6 of Set 6 | cuyo
# Processing Record 7 of Set 6 | thinadhoo
# Processing Record 8 of Set 6 | homer
# Processing Record 9 of Set 6 | senneterre
# Processing Record 10 of Set 6 | andalan
# Processing Record 11 of Set 6 | los llanos de aridane
# Processing Record 12 of Set 6 | qurayyat
# Processing Record 13 of Set 6 | provideniya
# Processing Record 14 of Set 6 | biak
# Processing Record 15 of Set 6 | acari
# Processing Record 16 of Set 6 | champerico
# Processing Record 17 of Set 6 | maniitsoq
# Processing Record 18 of Set 6 | grindavik
# Processing Record 19 of Set 6 | governador valadares
# Processing Record 20 of Set 6 | sorland
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | amahai
# Processing Record 23 of Set 6 | jinchang
# Processing Record 24 of Set 6 | louis trichardt
# Processing Record 25 of Set 6 | longyearbyen
# Processing Record 26 of Set 6 | vaitape
# Processing Record 27 of Set 6 | puerto suarez
# Processing Record 28 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 6 | katsuura
# Processing Record 30 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 6 | arraial do cabo
# Processing Record 32 of Set 6 | auki
# Processing Record 33 of Set 6 | linhares
# Processing Record 34 of Set 6 | shalakusha
# Processing Record 35 of Set 6 | chelmza
# Processing Record 36 of Set 6 | bud
# Processing Record 37 of Set 6 | kruisfontein
# Processing Record 38 of Set 6 | solnechnyy
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | souillac
# Processing Record 42 of Set 6 | mandiana
# Processing Record 43 of Set 6 | inirida
# Processing Record 44 of Set 6 | sioux lookout
# Processing Record 45 of Set 6 | chengde
# Processing Record 46 of Set 6 | berlevag
# Processing Record 47 of Set 6 | yurimaguas
# Processing Record 48 of Set 6 | hambantota
# Processing Record 49 of Set 6 | sibolga
# Processing Record 50 of Set 6 | yerbogachen
# Processing Record 1 of Set 7 | lake forest
# Processing Record 2 of Set 7 | talnakh
# Processing Record 3 of Set 7 | erenhot
# Processing Record 4 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 7 | saldanha
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | poso
# Processing Record 8 of Set 7 | beloha
# Processing Record 9 of Set 7 | mikkeli
# Processing Record 10 of Set 7 | qiongshan
# Processing Record 11 of Set 7 | bonavista
# Processing Record 12 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 13 of Set 7 | san juan
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | santa pola
# Processing Record 16 of Set 7 | benguela
# Processing Record 17 of Set 7 | jiuquan
# Processing Record 18 of Set 7 | lebu
# Processing Record 19 of Set 7 | manati
# Processing Record 20 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 21 of Set 7 | ambilobe
# Processing Record 22 of Set 7 | dyatkovo
# Processing Record 23 of Set 7 | mahibadhoo
# Processing Record 24 of Set 7 | djougou
# Processing Record 25 of Set 7 | itoigawa
# Processing Record 26 of Set 7 | pop
# Processing Record 27 of Set 7 | la roche-sur-yon
# Processing Record 28 of Set 7 | tromso
# Processing Record 29 of Set 7 | coahuayana
# Processing Record 30 of Set 7 | rosarito
# Processing Record 31 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 7 | masty
# Processing Record 33 of Set 7 | ancud
# Processing Record 34 of Set 7 | ampanihy
# Processing Record 35 of Set 7 | diamantino
# Processing Record 36 of Set 7 | eenhana
# Processing Record 37 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 7 | conceicao do araguaia
# Processing Record 39 of Set 7 | oyem
# Processing Record 40 of Set 7 | manggar
# Processing Record 41 of Set 7 | limbang
# Processing Record 42 of Set 7 | nehe
# Processing Record 43 of Set 7 | mehamn
# Processing Record 44 of Set 7 | port macquarie
# Processing Record 45 of Set 7 | kjollefjord
# Processing Record 46 of Set 7 | hokitika
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | ossora
# Processing Record 50 of Set 7 | ketchikan
# Processing Record 1 of Set 8 | yangambi
# Processing Record 2 of Set 8 | jardim
# Processing Record 3 of Set 8 | iqaluit
# Processing Record 4 of Set 8 | bouna
# Processing Record 5 of Set 8 | tazovskiy
# Processing Record 6 of Set 8 | campos novos
# Processing Record 7 of Set 8 | nemuro
# Processing Record 8 of Set 8 | alyangula
# Processing Record 9 of Set 8 | asfi
# Processing Record 10 of Set 8 | skopelos
# Processing Record 11 of Set 8 | coihaique
# Processing Record 12 of Set 8 | sault sainte marie
# Processing Record 13 of Set 8 | ruy barbosa
# Processing Record 14 of Set 8 | vacaria
# Processing Record 15 of Set 8 | imeni poliny osipenko
# Processing Record 16 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 8 | yaan
# Processing Record 18 of Set 8 | santa lucia
# Processing Record 19 of Set 8 | ancona
# Processing Record 20 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 8 | vardo
# Processing Record 22 of Set 8 | kismayo
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | nador
# Processing Record 25 of Set 8 | balsta
# Processing Record 26 of Set 8 | padilla
# Processing Record 27 of Set 8 | pelotas
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | tura
# Processing Record 30 of Set 8 | toccoa
# Processing Record 31 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 32 of Set 8 | tanout
# Processing Record 33 of Set 8 | ginda
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | dasoguz
# Processing Record 36 of Set 8 | mahebourg
# Processing Record 37 of Set 8 | zlutice
# Processing Record 38 of Set 8 | san cosme y damian
# Processing Record 39 of Set 8 | linqiong
# Processing Record 40 of Set 8 | bongandanga
# Processing Record 41 of Set 8 | saint anthony
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | primo tapia
# Processing Record 44 of Set 8 | porbandar
# Processing Record 45 of Set 8 | deputatskiy
# Processing Record 46 of Set 8 | nanakuli
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | dromolaxia
# Processing Record 49 of Set 8 | leninsk-kuznetskiy
# Processing Record 50 of Set 8 | beaufort
# Processing Record 1 of Set 9 | phulabani
# Processing Record 2 of Set 9 | flin flon
# Processing Record 3 of Set 9 | maridi
# Processing Record 4 of Set 9 | farakka
# Processing Record 5 of Set 9 | mount isa
# Processing Record 6 of Set 9 | danielskuil
# Processing Record 7 of Set 9 | sinnamary
# Processing Record 8 of Set 9 | santa rosalia
# Processing Record 9 of Set 9 | belyy yar
# Processing Record 10 of Set 9 | lompoc
# Processing Record 11 of Set 9 | kerema
# Processing Record 12 of Set 9 | binga
# Processing Record 13 of Set 9 | abalak
# Processing Record 14 of Set 9 | tiarei
# Processing Record 15 of Set 9 | kamenka
# Processing Record 16 of Set 9 | kasama
# Processing Record 17 of Set 9 | omboue
# Processing Record 18 of Set 9 | mata
# Processing Record 19 of Set 9 | tungor
# Processing Record 20 of Set 9 | itaituba
# Processing Record 21 of Set 9 | cleethorpes
# Processing Record 22 of Set 9 | gamba
# Processing Record 23 of Set 9 | chumikan
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | mufumbwe
# Processing Record 26 of Set 9 | pozo colorado
# Processing Record 27 of Set 9 | yashkul
# Processing Record 28 of Set 9 | takapau
# Processing Record 29 of Set 9 | ruthin
# Processing Record 30 of Set 9 | mananara
# Processing Record 31 of Set 9 | osypenko
# Processing Record 32 of Set 9 | porto novo
# Processing Record 33 of Set 9 | orcopampa
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | tilichiki
# Processing Record 36 of Set 9 | yuksekova
# Processing Record 37 of Set 9 | ibra
# Processing Record 38 of Set 9 | rute
# Processing Record 39 of Set 9 | phan thiet
# Processing Record 40 of Set 9 | baykit
# Processing Record 41 of Set 9 | oksfjord
# Processing Record 42 of Set 9 | san quintin
# Processing Record 43 of Set 9 | muko
# Processing Record 44 of Set 9 | margate
# Processing Record 45 of Set 9 | karratha
# Processing Record 46 of Set 9 | narsaq
# Processing Record 47 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 48 of Set 9 | pokrovsk
# Processing Record 49 of Set 9 | hanna
# Processing Record 50 of Set 9 | san carlos
# Processing Record 1 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 10 | hobyo
# Processing Record 3 of Set 10 | kitui
# Processing Record 4 of Set 10 | kaitangata
# Processing Record 5 of Set 10 | mountain home
# Processing Record 6 of Set 10 | dongdu
# Processing Record 7 of Set 10 | palkino
# Processing Record 8 of Set 10 | inuvik
# Processing Record 9 of Set 10 | krasnoyarsk
# Processing Record 10 of Set 10 | koster
# Processing Record 11 of Set 10 | neiafu
# Processing Record 12 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 10 | ugoofaaru
# Processing Record 14 of Set 10 | eyl
# Processing Record 15 of Set 10 | jeremoabo
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | kavaratti
# Processing Record 18 of Set 10 | fiumicino
# Processing Record 19 of Set 10 | windsor
# Processing Record 20 of Set 10 | middelburg
# Processing Record 21 of Set 10 | svetlyy
# Processing Record 22 of Set 10 | moussoro
# Processing Record 23 of Set 10 | silistea
# Processing Record 24 of Set 10 | swakopmund
# Processing Record 25 of Set 10 | sao sebastiao
# Processing Record 26 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 27 of Set 10 | tyazhinskiy
# Processing Record 28 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 10 | waipawa
# Processing Record 30 of Set 10 | moranbah
# Processing Record 31 of Set 10 | palana
# Processing Record 32 of Set 10 | portland
# Processing Record 33 of Set 10 | san carlos de bariloche
# Processing Record 34 of Set 10 | baturaja
# Processing Record 35 of Set 10 | newport
# Processing Record 36 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | marzuq
# Processing Record 38 of Set 10 | clyde river
# Processing Record 39 of Set 10 | pogar
# Processing Record 40 of Set 10 | whitecourt
# Processing Record 41 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 10 | yarada
# Processing Record 43 of Set 10 | joshimath
# Processing Record 44 of Set 10 | altay
# Processing Record 45 of Set 10 | balykshi
# Processing Record 46 of Set 10 | musoma
# Processing Record 47 of Set 10 | dhidhdhoo
# Processing Record 48 of Set 10 | jalu
# Processing Record 49 of Set 10 | tupancireta
# Processing Record 50 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 11 | cabedelo
# Processing Record 2 of Set 11 | tuzha
# Processing Record 3 of Set 11 | nam som
# Processing Record 4 of Set 11 | qandala
# Processing Record 5 of Set 11 | guaratinga
# Processing Record 6 of Set 11 | plettenberg bay
# Processing Record 7 of Set 11 | san felipe
# Processing Record 8 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 11 | riyadh
# Processing Record 10 of Set 11 | santiago del estero
# Processing Record 11 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 11 | vanino
# Processing Record 13 of Set 11 | tiksi
# Processing Record 14 of Set 11 | tucuma
# Processing Record 15 of Set 11 | horta
# Processing Record 16 of Set 11 | ludvika
# Processing Record 17 of Set 11 | pacific grove
# Processing Record 18 of Set 11 | nara
# Processing Record 19 of Set 11 | bara
# Processing Record 20 of Set 11 | gorkovskoye
# City not found. Skipping...
# Processing Record 21 of Set 11 | zaragoza
# Processing Record 22 of Set 11 | esperance
# Processing Record 23 of Set 11 | la ronge
# Processing Record 24 of Set 11 | sarkeresztur
# Processing Record 25 of Set 11 | peniche
# Processing Record 26 of Set 11 | kintinku
# Processing Record 27 of Set 11 | leshukonskoye
# Processing Record 28 of Set 11 | aleksandrov gay
# Processing Record 29 of Set 11 | rioblanco
# Processing Record 30 of Set 11 | necochea
# Processing Record 31 of Set 11 | jieshi
# Processing Record 32 of Set 11 | georgiyevka
# Processing Record 33 of Set 11 | turukhansk
# Processing Record 34 of Set 11 | manokwari
# Processing Record 35 of Set 11 | bilma
# Processing Record 36 of Set 11 | meulaboh
# Processing Record 37 of Set 11 | yining
# Processing Record 38 of Set 11 | bar harbor
# Processing Record 39 of Set 11 | havre-saint-pierre
# Processing Record 40 of Set 11 | prachuap khiri khan
# Processing Record 41 of Set 11 | oranjemund
# Processing Record 42 of Set 11 | sakakah
# Processing Record 43 of Set 11 | surany
# Processing Record 44 of Set 11 | college
# Processing Record 45 of Set 11 | araouane
# Processing Record 46 of Set 11 | oltu
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | friedberg
# Processing Record 49 of Set 11 | kamaishi
# Processing Record 50 of Set 11 | iisalmi
# Processing Record 1 of Set 12 | ayagoz
# Processing Record 2 of Set 12 | aksu
# Processing Record 3 of Set 12 | samut songkhram
# Processing Record 4 of Set 12 | maxixe
# Processing Record 5 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 6 of Set 12 | cooma
# Processing Record 7 of Set 12 | bosaso
# Processing Record 8 of Set 12 | klaksvik
# Processing Record 9 of Set 12 | sozimskiy
# Processing Record 10 of Set 12 | yar-sale
# Processing Record 11 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 12 | salice salentino
# Processing Record 13 of Set 12 | husavik
# Processing Record 14 of Set 12 | rivera
# Processing Record 15 of Set 12 | asau
# Processing Record 16 of Set 12 | yantal
# Processing Record 17 of Set 12 | pontal do parana
# Processing Record 18 of Set 12 | pisco
# Processing Record 19 of Set 12 | tatishchevo
# Processing Record 20 of Set 12 | copiapo
# Processing Record 21 of Set 12 | sur
# Processing Record 22 of Set 12 | paamiut
# Processing Record 23 of Set 12 | mwinilunga
# Processing Record 24 of Set 12 | guarapari
# Processing Record 25 of Set 12 | constitucion
# Processing Record 26 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 12 | karakol
# Processing Record 28 of Set 12 | ellsworth
# Processing Record 29 of Set 12 | uglovskoye
# Processing Record 30 of Set 12 | ornskoldsvik
# Processing Record 31 of Set 12 | manbij
# Processing Record 32 of Set 12 | phanat nikhom
# Processing Record 33 of Set 12 | westport
# Processing Record 34 of Set 12 | petilia policastro
# Processing Record 35 of Set 12 | saint-augustin
# Processing Record 36 of Set 12 | zhigansk
# Processing Record 37 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 12 | jefferson city
# Processing Record 39 of Set 12 | betare oya
# Processing Record 40 of Set 12 | luderitz
# Processing Record 41 of Set 12 | bozeman
# Processing Record 42 of Set 12 | ukiah
# Processing Record 43 of Set 12 | tadine
# Processing Record 44 of Set 12 | maragogi
# Processing Record 45 of Set 12 | voghera
# Processing Record 46 of Set 12 | mangai
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | puerto narino
# Processing Record 49 of Set 12 | fuerte olimpo
# Processing Record 50 of Set 12 | bereda
# Processing Record 1 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 13 | egvekinot
# Processing Record 3 of Set 13 | ahuimanu
# Processing Record 4 of Set 13 | seljord
# Processing Record 5 of Set 13 | mocuba
# Processing Record 6 of Set 13 | naantali
# Processing Record 7 of Set 13 | tupaciguara
# Processing Record 8 of Set 13 | high rock
# Processing Record 9 of Set 13 | tangping
# Processing Record 10 of Set 13 | ulladulla
# Processing Record 11 of Set 13 | dabeiba
# Processing Record 12 of Set 13 | udachnyy
# Processing Record 13 of Set 13 | zhongxing
# Processing Record 14 of Set 13 | tezu
# Processing Record 15 of Set 13 | longyan
# Processing Record 16 of Set 13 | ganzhou
# Processing Record 17 of Set 13 | gat
# Processing Record 18 of Set 13 | panacan
# Processing Record 19 of Set 13 | damghan
# Processing Record 20 of Set 13 | west wendover
# Processing Record 21 of Set 13 | monrovia
# Processing Record 22 of Set 13 | masvingo
# Processing Record 23 of Set 13 | port augusta
# Processing Record 24 of Set 13 | karema
# Processing Record 25 of Set 13 | vanavara
# Processing Record 26 of Set 13 | gwadar
# Processing Record 27 of Set 13 | leningradskiy
# Processing Record 28 of Set 13 | lorengau
# Processing Record 29 of Set 13 | panaba
# Processing Record 30 of Set 13 | loralai
# Processing Record 31 of Set 13 | filingue
# Processing Record 32 of Set 13 | warrington
# Processing Record 33 of Set 13 | amarante do maranhao
# Processing Record 34 of Set 13 | kulhudhuffushi
# Processing Record 35 of Set 13 | ust-nera
# Processing Record 36 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 13 | komsomolskiy
# Processing Record 38 of Set 13 | itarema
# Processing Record 39 of Set 13 | mayo
# Processing Record 40 of Set 13 | anadyr
# Processing Record 41 of Set 13 | isla vista
# Processing Record 42 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 13 | porvoo
# Processing Record 44 of Set 13 | santa marta
# Processing Record 45 of Set 13 | sangmelima
# Processing Record 46 of Set 13 | korla
# Processing Record 47 of Set 13 | kununurra
# Processing Record 48 of Set 13 | karpogory
# Processing Record 49 of Set 13 | kochubey
# Processing Record 50 of Set 13 | malinovoye ozero
# Processing Record 1 of Set 14 | kangaatsiaq
# Processing Record 2 of Set 14 | yaransk
# Processing Record 3 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 4 of Set 14 | derzhavinsk
# Processing Record 5 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 14 | shelburne
# Processing Record 7 of Set 14 | zeya
# Processing Record 8 of Set 14 | taoudenni
# Processing Record 9 of Set 14 | buala
# Processing Record 10 of Set 14 | kandi
# Processing Record 11 of Set 14 | uivar
# Processing Record 12 of Set 14 | quelimane
# Processing Record 13 of Set 14 | kroya
# Processing Record 14 of Set 14 | leh
# Processing Record 15 of Set 14 | qaqortoq
# Processing Record 16 of Set 14 | freeport
# Processing Record 17 of Set 14 | parakan
# Processing Record 18 of Set 14 | comodoro rivadavia
# Processing Record 19 of Set 14 | benjamin constant
# Processing Record 20 of Set 14 | olga
# Processing Record 21 of Set 14 | baiao
# Processing Record 22 of Set 14 | san juan de la maguana
# Processing Record 23 of Set 14 | port blair
# Processing Record 24 of Set 14 | berck
# Processing Record 25 of Set 14 | moju
# Processing Record 26 of Set 14 | puerto madryn
# Processing Record 27 of Set 14 | polunochnoye
# Processing Record 28 of Set 14 | sabha
# Processing Record 29 of Set 14 | matara
# Processing Record 30 of Set 14 | indramayu
# Processing Record 31 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 32 of Set 14 | aboso
# Processing Record 33 of Set 14 | zalalovo
# Processing Record 34 of Set 14 | yatou
# Processing Record 35 of Set 14 | venado
# Processing Record 36 of Set 14 | cortez
# Processing Record 37 of Set 14 | libano
# Processing Record 38 of Set 14 | medicine hat
# Processing Record 39 of Set 14 | san policarpo
# Processing Record 40 of Set 14 | axim
# Processing Record 41 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 14 | norman wells
# Processing Record 43 of Set 14 | aurad
# Processing Record 44 of Set 14 | dingle
# Processing Record 45 of Set 14 | wittmund
# Processing Record 46 of Set 14 | churapcha
# Processing Record 47 of Set 14 | muros
# Processing Record 48 of Set 14 | mersing
# Processing Record 49 of Set 14 | amboasary
# Processing Record 50 of Set 14 | kasongo-lunda
# Processing Record 1 of Set 15 | lasa
# Processing Record 2 of Set 15 | oktyabrskiy
# Processing Record 3 of Set 15 | pontes e lacerda
# Processing Record 4 of Set 15 | smithers
# Processing Record 5 of Set 15 | calbuco
# Processing Record 6 of Set 15 | barao de melgaco
# Processing Record 7 of Set 15 | baracoa
# Processing Record 8 of Set 15 | taltal
# Processing Record 9 of Set 15 | cotonou
# Processing Record 10 of Set 15 | peterhead
# Processing Record 11 of Set 15 | maldonado
# Processing Record 12 of Set 15 | bajil
# Processing Record 13 of Set 15 | patos
# Processing Record 14 of Set 15 | seydisehir
# Processing Record 15 of Set 15 | inongo
# Processing Record 16 of Set 15 | vinh
# Processing Record 17 of Set 15 | morgan city
# Processing Record 18 of Set 15 | xiongzhou
# Processing Record 19 of Set 15 | stephenville
# Processing Record 20 of Set 15 | mikhaylovka
# Processing Record 21 of Set 15 | faya
# Processing Record 22 of Set 15 | shestakovo
# Processing Record 23 of Set 15 | aguada de pasajeros
# Processing Record 24 of Set 15 | voiron
# Processing Record 25 of Set 15 | caravelas
# Processing Record 26 of Set 15 | cheyenne
# Processing Record 27 of Set 15 | capreol
# Processing Record 28 of Set 15 | bendigo
# Processing Record 29 of Set 15 | newtonmore
# Processing Record 30 of Set 15 | dera bugti
# Processing Record 31 of Set 15 | kabinda
# Processing Record 32 of Set 15 | usumatlan
# Processing Record 33 of Set 15 | kalmunai
# Processing Record 34 of Set 15 | assiniboia
# Processing Record 35 of Set 15 | ternate
# Processing Record 36 of Set 15 | khuzdar
# Processing Record 37 of Set 15 | xuanwu
# Processing Record 38 of Set 15 | anqiu
# Processing Record 39 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 15 | gao
# Processing Record 42 of Set 15 | azul
# Processing Record 43 of Set 15 | jaslo
# Processing Record 44 of Set 15 | aripuana
# Processing Record 45 of Set 15 | mana
# Processing Record 46 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 15 | kawalu
# Processing Record 48 of Set 15 | nurota
# Processing Record 49 of Set 15 | encruzilhada
# Processing Record 50 of Set 15 | maumere
# Processing Record 1 of Set 16 | sungairaya
# Processing Record 2 of Set 16 | pyaozerskiy
# Processing Record 3 of Set 16 | haimen
# Processing Record 4 of Set 16 | sri aman
# Processing Record 5 of Set 16 | matay
# Processing Record 6 of Set 16 | middleton
# Processing Record 7 of Set 16 | koumac
# Processing Record 8 of Set 16 | khorixas
# Processing Record 9 of Set 16 | gogrial
# Processing Record 10 of Set 16 | klyuchi
# Processing Record 11 of Set 16 | bilibino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Palmer      US  42.1584  -72.3287     37.15        87         100
# 1         Kavieng      PG  -2.5744  150.7967     83.48        70          97
# 2       Saskylakh      RU  71.9167  114.0833    -41.22       100          63
# 3         Rikitea      PF -23.1203 -134.9692     78.15        66          98
# 4           Vaini      TO -21.2000 -175.2000     87.96        79          40
# 5    Punta Arenas      CL -53.1500  -70.9167     51.91        93           0
# 6          Avarua      CK -21.2078 -159.7750     82.45        78          75
# 7        Bereznik      RU  62.8551   42.7072     34.95        87         100
# 8         Trimbak      IN  19.9333   73.5500     59.00        37           8
# 9  Cabo San Lucas      MX  22.8909 -109.9124     68.50        54         100
#
#    Wind Speed Current Description
# 0        5.75       moderate rain
# 1        4.41          light rain
# 2        4.41       broken clouds
# 3        2.17     overcast clouds
# 4       13.80          light rain
# 5        5.75           clear sky
# 6       18.41       broken clouds
# 7       11.43     overcast clouds
# 8        2.37           clear sky
# 9        6.91     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Palmer      US  42.1584  -72.3287     37.15        87         100
# 1    Kavieng      PG  -2.5744  150.7967     83.48        70          97
# 2  Saskylakh      RU  71.9167  114.0833    -41.22       100          63
# 3    Rikitea      PF -23.1203 -134.9692     78.15        66          98
# 4      Vaini      TO -21.2000 -175.2000     87.96        79          40
#
#    Wind Speed Current Description
# 0        5.75       moderate rain
# 1        4.41          light rain
# 2        4.41       broken clouds
# 3        2.17     overcast clouds
# 4       13.80          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
outputData_file = "weather_data/cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(outputData_file, index_label="City_ID")
